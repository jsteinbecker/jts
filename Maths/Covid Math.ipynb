# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv("/Users/joshsteinbecker/jts_project/Maths/US Covid DR by Vax.csv",",",comment="#")
df
# Out:
# /Users/joshsteinbecker/Library/r-miniconda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Entity  Code         Day  Fully vaccinated (all vaccines)  \
# 0       12-17   NaN  2021-04-10                         0.000000
# 1       12-17   NaN  2021-04-17                         0.000000
# 2       12-17   NaN  2021-04-24                         0.000000
# 3       12-17   NaN  2021-05-01                         0.000000
# 4       12-17   NaN  2021-05-08                         0.000000
# ..        ...   ...         ...                              ...
# 205  All ages   NaN  2021-10-02                         0.827608
# 206  All ages   NaN  2021-10-09                         0.732598
# 207  All ages   NaN  2021-10-16                         0.657364
# ...

# %%
x = df.plot('Day',
      ['Fully vaccinated (all vaccines)','Unvaccinated'], 
      title="COVID Deaths by Vaccine Status per 100,000",
      figsize = (12,4))

# %%
# RELATIVE RISK OF DEATH DUE TO UNVACCINATED STATUS
#           value read as 
#           "X-times more likely to die from COVID if you are unvaccinated"
rr = df["Unvaccinated"] / df['Fully vaccinated (all vaccines)'] 
rr = rr.tail(153)
for x in df:
      print(x)
sum = 0
for x in rr:
      sum = sum + x
      print (x)
print(sum)
print(len(rr))
avg = sum / len(rr)
print(avg)
# Out:
# Entity
# Code
# Day
# Fully vaccinated (all vaccines)
# Johnson&Johnson
# Pfizer/BioNTech
# Moderna
# Unvaccinated
# 16.91406629992777
# 36.82738217768147
# 26.007335919095198
# 9.768245257889395
# 11.51143597373054
# 21.512078147143043
# 28.940470628947143
# 30.313177557184982
# 28.956171679550245
# 50.296779144848955
# inf
# 52.186584154694124
# 30.72255094994978
# 8.467967809384175
# 39.71635573237375
# 17.214390091502565
# 22.103105752904018
# 28.84814655206643
# 31.882823218106612
# 20.172435078645933
# 30.984589512861415
# 37.72081009952625
# 56.33117144210846
# 39.853274984986975
# 32.724078151927735
# 35.23055394860645
# 38.138227015326414
# 32.81832655511868
# 25.611765889858233
# 60.252436330114676
# 26.05011552132467
# 32.50682812458488
# 38.74743238663323
# 23.082832746023172
# 14.243957246463795
# 18.873131211159645
# 15.466299661926135
# 12.422037573682656
# 34.70444145201758
# 18.078629562453642
# 14.945280232576899
# 12.799306977530312
# 20.40801685585735
# ...
